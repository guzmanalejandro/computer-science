# %% [markdown]
# # <span class="tema">(Python)</span> Pràctica dels conceptes inicials

# %%
# Completa els programes següents segons les indicacions donades
# després crida'ls i comprova que funcionen

def nom_funcio (nom):      # falta el nom de la funció
    print(nom)
    

def calcul(x, y):  # algun signe?
    print(x + y)
    
def calcul_per_teclat():
    x = eval(input("Digues un nombre:"))
    y = eval(input("Digues un altre nombre"))          # completa-ho
    print(x * y)
    
def elevat_a_3(n):
    print(n**3)      # com es feia la potència?

# %%
nom_funcio("Noah")                 # aquí falta una crida
# Out:
# Noah

# %%
calcul(43,2)
# Out:
# 45

# %%
calcul_per_teclat()
# Out:
# Digues un nombre:2
# Digues un altre nombre3
# 6

# %%
elevat_a_3(5)
# Out:
# 125

# %%
# Corregeix, si cal, les següents instruccions

print (3)
print ("hola")
print(3)
print("hola")
# Out:
# 3
# hola
# 3
# hola

# %% [markdown]
# Indica al costat de cada nom de funció o variable si és correcte o no
# (segons les indicacions donades a teoria):
#
# + Hola: en minúscula millor ('hola').
# + FuncioMagnifica: funcio_magnifica.
# + 1que_vol: no començar una funció amb números ('que_vol').
# + funcio magnifica: no pot anar separat, funcio_magnifica.
# + funcio_magnifica: CORRECTE.
# + funcio-magnifica: la barra ha d'anar abaix, funcio_magnifica.
# + while: No és correcte perquè utilitza una paraula reservada.
# + CALCUL: Si és una constant, llavors és correcte. Però aquí entenem que pot ser una variable normal, llavors tampoc seria correcte.

# %% [markdown]
# Què fa "end=''" quan ho posem al final de print? busca-ho als apunts, experimenta i explica-ho.
#
# "end=''" si ho posem al final de print, evita que es faci un salt de línea (\n).

# %%
print("Noah",end='')
print("Márquez")
# Out:
# NoahMárquez

# %%
# Posa les instruccions per demanar la dada que s'indica seguint els patrons:
# Comprova de quin tipus és la variable resultant

nom = input("Digues el teu nom:")    

type(nom)  # per defecte input sempre llegeix una cadena

x = eval(input("Digues la teva edat:"))
           # si volem llegir un nombre hem de posar "eval"
type(x)
# Out:
# Digues el teu nom:Noah
# Digues la teva edat:18
# int

# %%
# demana la ciutat on viu
ciutat = input("Digues a quina ciutat vius:")
type(ciutat)
# Out:
# Digues a quina ciutat vius:Manresa
# str

# %%
# demana l'alçada
alcada = eval(input("Quant medeixes?:"))
type(alcada)
# Out:
# Quant medeixes?:1.8
# float

# %%
# demana quants germans i/o germanes té
siblings = eval(input("Quants germans i/o germanes tens?:"))
type(siblings)
# Out:
# Quants germans i/o germanes tens?:1
# int

# %%
# demana l'idioma preferent
idioma = input("Quin idioma parles amb més freqüència?:")
type(idioma)
# Out:
# Quin idioma parles amb més freqüència?:Espanyol
# str

# %%
# Escriu un programa per intercanviar 4 variables de valor
# inicialment x = 4, y = 5, w = 6, z = 7
# al final has d'aconseguir que x = 7, y =4, w = 5 i z = 6

x = 4
y = 5
w = 6
z = 7

x, y, w, z = z, x, y, w
print(x, y, w, z)
# Out:
# 7 4 5 6

# %%
# A partir del següent model, canvia els valors del for 
# per mostrar els valors demanats:

# %%
# Model, mostra els valors de 2 a 10 en salts de 3 en 3

for i in range (2,10,3):
    print(i)
# Out:
# 2
# 5
# 8

# %%
# Copia el model i canvia els valors per a que mostri 0 a 5 de 1 en 1
for i in range (0,6,1):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# Pots simplificar el codi de l'anterior casella amb els mateixos resultats?
for j in range(6):
    print(j)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# Copia el model i canvia els valors per a que es mostri 8,6,4
for i in range (8,2,-2):
    print(i)
# Out:
# 8
# 6
# 4

# %% [markdown]
# Escriu un programa que pregunti algunes dades personals i després les mostri per pantalla de manera ordenada.

# %%
print("Hola,")

nom = input("Com et dius?:")    

print("Hola,",nom)

x = eval(input("Quants anys tens?:"))
          
print ("I... ")

ciutat = input("A quina ciutat vius?:")

print(ciutat,"és una ciutat molt maca!")

alçada = eval(input("Quant medeixes?:"))

siblings = eval(input("Quants germans i/o germanes tens?:"))

idioma = input("Quin idioma parles amb més freqüència?:")

print("En resum, et dius",nom,", tens",x,"anys i vius a",ciutat,". Medeixes"
,alçada,"i tens",siblings,
"germans i/o germanes i l'idioma que parles més freqüentment és",idioma,".")
# Out:
# Hola,
# Com et dius?:Noah
# Hola, Noah
# Quants anys tens?:18
# I...
# A quina ciutat vius?:Manresa
# Manresa és una ciutat molt maca!
# Quant medeixes?:1.8
# Quants germans i/o germanes tens?:1
# Quin idioma parles amb més freqüència?:English
# En resum, et dius Noah , tens 18 anys i vius a Manresa . Medeixes 1.8 i tens 1 germans i/o germanes i l'idioma que parles més freqüentment és English .

# %% [markdown]
# <div id="peu">
# <p><a href="https://colab.research.google.com/github/algorismica2020/algorismica2020.github.io/blob/master/notebookscolab/PythonPractica1.ipynb"><img style="margin:-10px 10px 20px 0" width="150px" align="right" src="https://raw.githubusercontent.com/algorismica2019/problemes/master/assets/colab-badge.png?raw=1" alt="Obrir a Colab" title="Obrir i executar a Google Colaboratory"></a></p>
# </div>
