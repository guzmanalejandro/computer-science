# %% [markdown]
# Apunts:
#      https://algorismica2020.github.io/slides/dividir.html#1
#
# Recordatori del Teorema Master:
#
# *   **Cas 1**: T(n) = O(n^d) si a < b^d.
# *   **Cas 2**: T(n) = O(n^d \log n) si a = b^d.
# *   **Cas 3**: T(n) = O(n^{\log_b a}) si a > b^d.
#
# **QuickSort**:
#     https://drive.google.com/file/d/1EYQL5EqCh5e7q9_83NeyHrLE2p5nUSAj/view
#
# **Mediana**:
#     https://drive.google.com/file/d/1ssT3z_VJ1TMz0wX-6N2vpoeNqZu4o72z/view
