# %% [markdown]
# Un nombre, x, es diu apocalíptic si la xifra que representa 2^x conté la seqüència 666.

# %% [markdown]
# Escriu una funció que determini si un nombre és apocalíptic. Un cop escrit el programa, contesta les següents preguntes:
#
# • Quins dels segu ̈ents nombres s ́on apocalíptics? 157, 180, 192.
#
# • Dóna una llista amb tots els nombres apocalíptics entre 100 i 300.
#
# • Quants nombres apocalíptics hi ha menors que 5.000?

# %% [markdown]
# Reflexions previes: Fes aquestes reflexions abans de començar a programar:
#
# • Com podem saber si la seqüència 666 apareix al nombre? Amb el valor numèric de 2^x és dificil de saber, quin altre tipus de variable podem fer servir?
#
# •Explica els passos que fa l’algorisme en el cas apocaliptic(157)

# %% [markdown]
# Banc de proves: Defineix diversos exemples per comprovar la teva solució. Entre d’altres, executa les comprovacions següents:
#
#     assert apocaliptic(157) == True
#
#     assert apocaliptic(180) == False
#
#     assert apocaliptic(192) == True
#
#     assert llista_apocaliptics(100,300) == [157, 192, 218, 220, 222, 224, 226, 243, 245, 247, 251, 278, 285, 286, 287]
#
#     assert len(llista_apocaliptics(0,5000)) ==  2253

# %%
def apocaliptic(num):
  x = str(2**num)
  if '666' in x:
    return True
  else:
    return False

assert apocaliptic(157) == True
 
assert apocaliptic(180) == False
 
assert apocaliptic(192) == True


def llista_apocaliptics(minim, maxim):
  llista = []
  for i in range(minim, maxim):
    y = str(2**i)
    if '666' in y:
      llista.append(i)
      llista.sort()
  return llista

llista_apocaliptics(100, 300)
# Out:
# [157, 192, 218, 220, 222, 224, 226, 243, 245, 247, 251, 278, 285, 286, 287]
