# %% [markdown]
# Apunts:
#
#     -->https://algorismica2020.github.io/slides/hanoi.html#1
#
# Joc en linea:
#
#     -->https://www.mindgames.com/game/Tower+of+Hanoi

# %%
def moveTower(height,fromPole, toPole, withPole):  # height és el nombre de discs 
    if height >= 1:                                # que hi ha al pal origen
        moveTower(height-1,fromPole,withPole,toPole)
        moveDisk(fromPole,toPole)
        moveTower(height-1,withPole,toPole,fromPole)
    return
def moveDisk(fp,tp):
    print("moving disk from",fp,"to",tp)

moveTower(3,"A","B","C")
# Out:
# moving disk from A to B
# moving disk from A to C
# moving disk from B to C
# moving disk from A to B
# moving disk from C to A
# moving disk from C to B
# moving disk from A to B
