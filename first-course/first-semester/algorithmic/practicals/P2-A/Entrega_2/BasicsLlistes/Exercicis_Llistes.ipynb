# %% [markdown]
# Exercici 1: Llista de zeros
#
# Escriu una funció que donat un nombre  𝑛  crei una llista amb n zeros. No pots fer cap iteració.
#
# Exemple:
#
# zeros(4)
#
# [0, 0, 0, 0]

# %%
def zeros(n):
  return [0] * n

zeros(9)
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %% [markdown]
# Exercici 2: Llista selectiva
#
# Escriu una funció que donat un nombre  𝑛  i una llista, retorni una segona llista amb els elements de la llista inicials que són estrictament menors al nombre  𝑛  donat.
#
# Exemple:
#
# llistaSelectiva([1, 15, 5, 3, 2, 12, 99, 8, 6], 10)
#
# [1, 5, 3, 2, 8, 6]

# %%
def llistaSelectiva(list, n):
  newList = []
  for j in list:
    if j < n:
      newList.append(j)
  return newList

llistaSelectiva([1, 15, 5, 3, 2, 12, 99, 8, 6], 10)
# Out:
# [1, 5, 3, 2, 8, 6]

# %% [markdown]
# Exercici 6: Entrada en seqüència i càlculs sobre llistes
#
# Escriu un programa que demani un número a l'usuari repetidament fins que aquest introdueixi -99. Quan hagi acabat d'introduir els números mostra per pantalla la suma dels nombres introduits, quants nombres s'han introduit i la mitjana aritmètica.
#
# Consulta la documentació de Python per si hi ha funcions estàndards que et puguin ajudar.
#
# Exemple:
#
# Introdueix un número: 7
#
# Introdueix un número: 6
#
# Introdueix un número: -1
#
# Introdueix un número: -99
#
# S'han introduit 3 nombres, amb una suma total de 12, i una mitjana aritmètica de 4

# %%
def introduirNombres():
    llista = []
    x = int(input("Introdueix un número (-99 per acabar): "))
    while x != -99:
        llista.append(x)
        x = int(input("Introdueix un número (-99 per acabar): "))
    nombres = len(llista)
    suma = sum(llista)
    mitja = int(suma / nombres)
    print("S'han introduit", nombres, "nombres, amb una suma total de"
    ,suma, ", i una mitjana aritmètica de",mitja)

introduirNombres()
# Out:
# Introdueix un número (-99 per acabar): 7
# Introdueix un número (-99 per acabar): 6
# Introdueix un número (-99 per acabar): -1
# Introdueix un número (-99 per acabar): -99
# S'han introduit 3 nombres, amb una suma total de 12 , i una mitjana aritmètica de  4

# %% [markdown]
# Exercici 7: Entrada en seqüència i càlculs sobre llistes. Variant
#
# Escriu un programa que demani un número a l'usuari repetidament fins que aquest introdueixi -99. Ves recopilant els nombres en una llista. Quan hagi acabat d'introduir els números mostra per pantalla el mínim i el màxim de la llista.
#
# Consulta la documentació de Python per si hi ha funcions estàndards que et puguin ajudar.
#
# Exemple:
#
# Introdueix un número: 7
#
# Introdueix un número: 6
#
# Introdueix un número: -1
#
# Introdueix un número: -99
#
# El número màxim introduit és el 7 i el mínim el -1

# %%
def maxmin():
    llista = []
    xStr = eval(input("Introdueix un número (-99 per acabar): "))
    while xStr != -99:
        llista.append(xStr)
        xStr = eval(input("Introdueix un número (-99 per acabar): "))
    maxim = max(llista)
    minim = min(llista)
    print("El número màxim introduit és el", maxim, "i el mínim el", minim)

maxmin()
# Out:
# Introdueix un número (-99 per acabar): 7
# Introdueix un número (-99 per acabar): 6
# Introdueix un número (-99 per acabar): -1
# Introdueix un número (-99 per acabar): -99
# El número màxim introduit és el 7 i el mínim el -1

# %% [markdown]
# Exercici 8: Inici i final d'una llista
#
# Escriu un programa que donada una llista en retorni una de nova amb només el primer i el darrer element de la llista.
#
# Exemple:
#
# iniciFinal([3, 6, 1, 9, 10])
#
# [3, 10]

# %%
def iniciFinal(llista):
  return [llista[0], llista[-1]]

iniciFinal([3, 6, 1, 9, 10])
# Out:
# [3, 10]

# %% [markdown]
# Exercici 9: Canviar les paraules d'ordre
#
# Escriu una funció que donada una frase la retorni a l'usuari amb les paraules en ordre invers.
#
# Exemple:
#
# Em dic Andreu
#
# Andreu dic Em

# %%
def flippedWords(frase):
  return " ".join(frase.split()[::-1])

flippedWords('Em dic Andreu')
# Out:
# 'Andreu dic Em'
