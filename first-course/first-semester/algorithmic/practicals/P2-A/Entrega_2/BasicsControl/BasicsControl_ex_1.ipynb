# %% [markdown]
# Exercici 1: Mínim i màxim
#
# Escriu un programa que demani un número a l'usuari repetidament fins que aquest introdueixi -99. Quan hagi acabat d'introduir els números mostra per pantalla el mínim i el màxim de la llista.
#
# Exemple:
#
# Introdueix un número: 7
#
# Introdueix un número: 6
#
# Introdueix un número: -1
#
# Introdueix un número: -99
#
# El número màxim introduit és el 7 i el mínim el -1

# %%
def getLlista():
    llista = []
    xStr = eval(input("Entra un nombre (-99 per acabar): "))
    while xStr != -99:
        llista.append(xStr)
        xStr = eval(input("Entra un nombre (-99 per acabar): "))
    maxim = max(llista)
    minim = min(llista)
    print("El número màxim introduit és el", maxim, "i el mínim el", minim)

getLlista()
# Out:
# Entra un nombre (-99 per acabar): -1
# Entra un nombre (-99 per acabar): 2
# Entra un nombre (-99 per acabar): 9
# Entra un nombre (-99 per acabar): 10
# Entra un nombre (-99 per acabar): -99
# El número màxim introduit és el 10 i el mínim el -1
